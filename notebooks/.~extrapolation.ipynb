# %%
import sys, os, time, shutil, random
from pathlib import Path
_cwd = os.getcwd()
os.chdir(Path(_cwd)/'..')
from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:98% !important; }</style>"))
# %load_ext autoreload
# %autoreload 2
# %pdb
from yaml import dump
import omnifig as fig
import numpy as np
np.set_printoptions(linewidth=120)
import pickle
from tabulate import tabulate
from tqdm.notebook import tqdm
import torch
from torch import nn
import torch.nn.functional as F
import torch.distributions as distrib
import torch.multiprocessing as mp
# import torchvision.models
from torch.utils.data import Dataset, DataLoader, TensorDataset
import timm

# %matplotlib notebook
import matplotlib.pyplot as plt
#plt.switch_backend('Qt5Agg') #('Qt5Agg')
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.cm
from matplotlib import animation
import matplotlib as mpl
# mpl.rc('image', cmap='gray')
import seaborn as sns
import pandas as pd
from sklearn.preprocessing import normalize

# import gpumap
from c3linearize import linearize, class_graph

fig.initialize()

import omnilearn as learn
from omnilearn import models
from omnilearn import util
from omnilearn.data import InterventionSamplerBase

from sklearn.decomposition import PCA
import sklearn.datasets


from src import sample_full_interventions, response_mat, factor_reponses
from src.responses import sample_full_interventions

fig.initialize('sae')
from omnifig.projects import sae
import networkx as nx

# from src import sample_full_interventions, response_mat, factor_reponses
dataset = None
src = None
def viz(config): # Utility function to print out config objects nicely
    print(dump(config.pythonize()), end='')

# %%
device = 'cuda'
figure_dir = Path('../learn_rep/figures/extrapolation')
figure_dir = Path(r'C:\Users\anwan\OneDrive\Khan\research\learn_rep\figures\neurips')
# figure_dir = None
# figure_root = None
seed = 10
torch.manual_seed(seed)

src = None

num_nodes = 5

B = 48
N = num_nodes + 3
G = 32
C = 3
H, W = 100, 100
# H, W = 64, 64

# %%
dataset2 = fig.quick_run('load-data', name='3dshapes', mode='full', labeled=True, shuffle=False, seed=seed)
len(dataset)
# Out:
# | dataset: None (by default)
# | CREATING . (type=dataset)
# |  > num_workers: 0 (by default)
# |  > batch_size: 64 (by default)
# |  > shuffle: False
# |  > drop_last: False (by default)
# |  > step_device --> device: 'cuda' (by default)
# |  > infinite: False (by default)
# |  > extractor: None (by default)
# |  > allow_batched: True (by default)
# |  > split: {} (by default)
# |  > shuffle-split: True (by default)
# |  > split-src: 'train' (by default)
# |  > _dataset_type --> dataset-name --> name: '3dshapes'
# |  > _dataset_mod: [] (by default)
# |  > default_mode --> mode: 'full'
# |  > mode-aliases: {} (by default)
# |  > seed: 10
# |  > device: 'cuda' (by default)
# |  > pin_memory: False (by default)
# |  > epoch_seed --> seed: 10
# |  > skip_load: False (by default)
# |  > CREATING . (type=dataset/3dshapes)
# |  >  > mode: 'full'
# |  >  > labeled: True
# |  >  > label_type: 'class' (by default)
# |  >  > din: (3, 64, 64) (by default)
# |  >  > dout: 6 (by default)
# |  >  > device: 'cuda' (by default)
# |  >  > fid_ident: None (by default)
# |  >  > mode: 'full'
# |  >  > dataroot: None (by default)
# WARNING:omnilearn.op.datasets.disentangling: using the full dataset (train+test)
# WARNING:omnilearn.op.datasets.disentangling: using the full dataset (train+test)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-0dc4b792f8dc> in <module>
#       1 dataset2 = fig.quick_run('load-data', name='3dshapes', mode='full', labeled=True, shuffle=False, seed=seed)
# ----> 2 len(dataset)
#
# TypeError: object of type 'NoneType' has no len()

# %%
factors = dataset2.get_factor_order()
factor_sizes = dataset2.get_factor_sizes()
factors, factor_sizes

# %%
sampler = InterventionSamplerBase(dataset2)
# interventions = sample_full_interventions(sampler, num_groups=20, pbar=tqdm)

# %%
intervention_dim = 5
intervention_imgs = sampler.full_intervention(intervention_dim)
imgs = intervention_imgs
util.plot_imgs(imgs);

# %%
root = Path(r'C:\Users\anwan\Documents\workspace\exts')
root = Path(r'C:\Users\anwan\Documents\workspace\extrap')
# root = Path(r'C:\Users\anwan\Documents\workspace\trained_nets')
run_names = os.listdir(str(root))
run_names = [r for r in run_names if '210509' in r or '210510' in r or '210511' in r]
len(run_names)
# Out:
# 72

# %%
print(tabulate(enumerate(run_names)))
# Out:
# --  ---------------------------------------
#  0  3ds_ae_e-c12_d-c12_xas_210509-025523
#  1  3ds_ae_e-c12_d-c12_xa_210509-032547
#  2  3ds_ae_e-c12_d-s12_xas_210509-031807
#  3  3ds_ae_e-c12_d-s12_xas_210510-225704
#  4  3ds_ae_e-c12_d-s12_xa_210509-034134
#  5  3ds_ae_e-c12_d-s12_xa_210510-225710
#  6  3ds_ae_e-c12_d-s6_xas_210509-031807
#  7  3ds_ae_e-c12_d-s6_xa_210509-032839
#  8  3ds_model_xa-ae-both_210510-234926
#  9  3ds_model_xa-ae-both_210510-235528
# 10  3ds_model_xa-ae-both_210510-235828
# 11  3ds_model_xa-ae-both_210511-004641
# 12  3ds_model_xa-ae-dec_210510-234123
# 13  3ds_model_xa-ae-dec_210510-235348
# 14  3ds_model_xa-ae-dec_210510-235749
# 15  3ds_model_xa-ae-dec_210511-004543
# 16  3ds_model_xa-ae-enc_210510-234724
# 17  3ds_model_xa-ae-enc_210510-235528
# 18  3ds_model_xa-ae-enc_210510-235829
# 19  3ds_model_xa-ae-enc_210511-004541
# 20  3ds_model_xa-vae1-both_210510-235047
# 21  3ds_model_xa-vae1-both_210511-000429
# 22  3ds_model_xa-vae1-dec_210510-234925
# 23  3ds_model_xa-vae1-dec_210511-000325
# 24  3ds_model_xa-vae1-enc_210510-235047
# 25  3ds_model_xa-vae1-enc_210511-000429
# 26  3ds_model_xa-vae2-both_210510-235750
# 27  3ds_model_xa-vae2-dec_210510-235628
# 28  3ds_model_xa-vae2-enc_210510-235727
# 29  3ds_model_xa-vae4-both_210511-004642
# 30  3ds_model_xa-vae4-dec_210511-004641
# 31  3ds_model_xa-vae4-enc_210511-004642
# 32  3ds_model_xa-wae10-both_210510-234123
# 33  3ds_model_xa-wae10-dec_210510-233843
# 34  3ds_model_xa-wae10-enc_210510-234023
# 35  3ds_model_xas-ae-both_210510-230055
# 36  3ds_model_xas-ae-both_210510-233223
# 37  3ds_model_xas-ae-both_210510-233323
# 38  3ds_model_xas-ae-both_210511-004503
# 39  3ds_model_xas-ae-dec_210510-230055
# 40  3ds_model_xas-ae-dec_210510-232823
# 41  3ds_model_xas-ae-dec_210510-233223
# 42  3ds_model_xas-ae-dec_210511-004504
# 43  3ds_model_xas-ae-enc_210510-230055
# 44  3ds_model_xas-ae-enc_210510-233223
# 45  3ds_model_xas-ae-enc_210510-233223_2
# 46  3ds_model_xas-ae-enc_210511-004502
# 47  3ds_model_xas-vae1-both_210510-231319
# 48  3ds_model_xas-vae1-both_210510-233822
# 49  3ds_model_xas-vae1-dec_210510-231020
# 50  3ds_model_xas-vae1-dec_210510-233522
# 51  3ds_model_xas-vae1-enc_210510-231021
# 52  3ds_model_xas-vae1-enc_210510-233544
# 53  3ds_model_xas-vae2-both_210510-231919
# 54  3ds_model_xas-vae2-dec_210510-231718
# 55  3ds_model_xas-vae2-enc_210510-231820
# 56  3ds_model_xas-vae4-both_210510-232622
# 57  3ds_model_xas-vae4-dec_210510-232222
# 58  3ds_model_xas-vae4-enc_210510-232222
# 59  3ds_model_xas-wae10-both_210510-231021
# 60  3ds_model_xas-wae10-dec_210510-230055
# 61  3ds_model_xas-wae10-enc_210510-231021
# 62  3ds_vae1_e-c12_d-c12_xas_210509-025727
# 63  3ds_vae1_e-c12_d-c12_xa_210509-032630
# 64  3ds_vae1_e-l12_d-l12_xas_210509-032322
# 65  3ds_vae1_e-l12_d-l12_xa_210509-034134
# 66  3ds_vae2_e-c12_d-c12_xas_210509-025808
# 67  3ds_vae2_e-c12_d-c12_xa_210509-032839
# 68  3ds_vae4_e-c12_d-c12_xas_210509-025920
# 69  3ds_vae4_e-c12_d-c12_xa_210510-225724
# 70  3ds_wae10_e-c12_d-c12_xas_210509-025523
# 71  3ds_wae10_e-c12_d-c12_xa_210509-032547
# --  ---------------------------------------

# %%
# run_name = run_names[8]
# run_name = run_names[9]

# run_name

# %%
fig.get_config().silence()

# %%
runs = [fig.quick_run('load-run', path=v, root=str(root), **{'override.legacy':True, 'override.root': str(root)}) for v in run_names]
len(runs)
# Out:
# 72

# %%
run = runs[1]
run
# Out:
# INLINE_TIMED_SAE_RUN:3ds_ae_e-c12_d-c12_xa_210509-032547

# %%
info = run.get_config().pull('info')
info
# Out:
# {'arch_type': 'c12',
#  'dataset_type': '3ds',
#  'dec_type': 'c12',
#  'enc_type': 'c12',
#  'extra': 'xa',
#  'model_type': 'ae',
#  'size': 64}

# %%
cut = 'xas'
# cut = 'xa'

# %%
srcs = {}
bad = None
byname = {r.name:r for r in runs}
for run in runs:
    if f'{cut}-' in run.name or f'{cut}_' in run.name:
        A = run.get_config()
        info = A.pull('info')
        if 'model_type' in info:
            if 'wae' == info['model_type']:
                run.code = 'WAE'
            elif 'l' in info['dec_type']:
                run.code = 'LVAE' + info['dec_type'][1:]
            elif 's' in info['dec_type']:
                run.code = ('SAE' if A.pull('model.decoder.split-style',True) else 'AdaAE') + info['dec_type'][1:]
            elif info['model_type'] == 'vae' and 'l' not in info['dec_type']:
                run.code = 'VAE{}'.format(A.pull('reg-wt'))
            elif info['model_type'] == 'ae' and info['dec_type'] == 'c12':
                run.code = 'AE'
#             elif info['model_type'] == 'vae':
#                 run.code = 'VAE'
#                 pass
            else:
                bad = run
                break
            run.updates = {'self':run}
            srcs[run.code] = run
for run in runs:
    if f'{cut}-' in run.name or f'{cut}_' in run.name:
        A = run.get_config()
        info = A.pull('info')
        if 'model_type' not in info:
            src = byname[A.pull('load-model')]
            src.updates[info['extra'].split('-')[-1]] = run
bad

# %%
srcs
# Out:
# {'AE': INLINE_TIMED_SAE_RUN:3ds_ae_e-c12_d-c12_xas_210509-025523,
#  'SAE12': INLINE_TIMED_SAE_RUN:3ds_ae_e-c12_d-s12_xas_210509-031807,
#  'AdaAE12': INLINE_TIMED_SAE_RUN:3ds_ae_e-c12_d-s12_xas_210510-225704,
#  'SAE6': INLINE_TIMED_SAE_RUN:3ds_ae_e-c12_d-s6_xas_210509-031807,
#  'VAE1': INLINE_TIMED_SAE_RUN:3ds_vae1_e-c12_d-c12_xas_210509-025727,
#  'LVAE12': INLINE_TIMED_SAE_RUN:3ds_vae1_e-l12_d-l12_xas_210509-032322,
#  'VAE2': INLINE_TIMED_SAE_RUN:3ds_vae2_e-c12_d-c12_xas_210509-025808,
#  'VAE4': INLINE_TIMED_SAE_RUN:3ds_vae4_e-c12_d-c12_xas_210509-025920,
#  'WAE': INLINE_TIMED_SAE_RUN:3ds_wae10_e-c12_d-c12_xas_210509-025523}

# %%
mcat = 'AdaAE12'

# %%
docket = ['SAE12', 'SAE6', 'LVAE12', 'VAE1', 'VAE4', 'AdaAE12', 'AE', 'WAE']
skews = None

# %%
base = srcs['SAE12']

# %%
if dataset is None:
    dataset = base.get_dataset()
    dataset.switch_to('extra')

# %%
loader = dataset.get_loader(batch_size=128)

# %%
if docket is None:
    docket = list(srcs)
print(f'On the docket: {docket}')
losses = {doc: {} for doc in docket}
recs = {doc: {} for doc in docket}
starter = None
for i, (X, *other) in tqdm(enumerate(loader), total=len(loader)):
    if i == 25:
        break
    for basename in docket:
        base = srcs.get(basename, None)
        if base is None:
            print(f'{basename} not found')
            continue
        
        lss = losses[basename]
        rcs = recs[basename]
        sks = list(base.updates) if skews is None else skews
        
        for sk in sks:
            if sk not in lss:
                lss[sk] = []
            r = base.updates.get(sk, None)
            if r is None:
                print(f'{basename}-{sk} not found')
                continue
            model = r.get_model()
            with torch.no_grad():
                R, Q = model(X, ret_q=True)
                if isinstance(Q, distrib.Distribution):
                    Q = Q.mean
                L = F.mse_loss(X, R, reduction='none').reshape(X.size(0),-1).mean(-1)
            lss[sk].append(L.cpu())
            if sk not in rcs:
                rcs[sk] = R.cpu()
                starter = X
for d in losses.values():
    for k, ls in d.items():
        d[k] = torch.cat(ls)
# Out:
# On the docket: ['SAE12', 'SAE6', 'LVAE12', 'VAE1', 'VAE4', 'AdaAE12', 'AE', 'WAE']
#   0%|          | 0/800 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-303-2e88c8625748> in <module>
#      31                     Q = Q.mean
#      32                 L = F.mse_loss(X, R, reduction='none').reshape(X.size(0),-1).mean(-1)
# ---> 33             lss[sk].append(L.cpu())
#      34             if sk not in rcs:
#      35                 rcs[sk] = R.cpu()
#
# KeyboardInterrupt:

# %%
{k:len(v) for k,v in losses.items()}

# %%
mkeys = list(base.updates)
mkeys = ['self', 'enc', 'dec', 'both']
mkeys

# %%
stat_fns = {
    'mean': lambda x: x.mean(-1),#.tolist(),
    '90%': lambda x: x.quantile(0.9, dim=1),#.tolist(),
}
statorder = ['mean', '90%']

# %%
stats = {}
for k, ls in losses.items():
    L = torch.stack([ls[key] for key in mkeys])
    stats[k] = torch.stack([stat_fns[name](L) for name in statorder])
stats.keys()

# %%
rows = []

for doc in docket:
    
    row = [doc]
    
    sts = stats[doc]
    
    row.extend([f'{x*1000:.2f}' for x in sts.t().reshape(-1).tolist()])
    
    rows.append(row)

# %%
from itertools import product

# %%
headers = ['Model', *[f'{k}-{s}' for k,s in product(mkeys, statorder)]]
headers
# Out:
# ['Model',
#  'self-mean',
#  'self-90%',
#  'enc-mean',
#  'enc-90%',
#  'dec-mean',
#  'dec-90%',
#  'both-mean',
#  'both-90%']

# %%
print(tabulate(rows, headers=headers, tablefmt='latex_raw'))
# Out:
# \begin{tabular}{lrrrrrrrr}
# \hline
#  Model   &   self-mean &   self-90% &   enc-mean &   enc-90% &   dec-mean &   dec-90% &   both-mean &   both-90% \\
# \hline
#  SAE12   &        4.88 &       8.22 &       2.64 &      4.69 &       0.78 &      1.2  &        0.44 &       0.57 \\
#  SAE6    &        4.84 &       8.15 &       3.47 &      6    &       0.72 &      1.27 &        0.38 &       0.49 \\
#  LVAE12  &        6.89 &      11.7  &       3.83 &      6.3  &       1.57 &      2.38 &        0.78 &       1.04 \\
#  VAE1    &        5.16 &       8.86 &       3.09 &      4.94 &       1    &      1.7  &        0.51 &       0.68 \\
#  VAE4    &        5.67 &       9.49 &       3.98 &      6.28 &       1.5  &      2.68 &        0.81 &       1.15 \\
#  AdaAE12 &        4.79 &       8.3  &       2.94 &      5.12 &       0.59 &      0.81 &        0.41 &       0.54 \\
#  AE      &        4.97 &       8.43 &       2.96 &      5.37 &       0.61 &      0.87 &        0.45 &       0.59 \\
#  WAE     &        4.79 &       8.22 &       3.07 &      5.46 &       0.69 &      0.97 &        0.44 &       0.58 \\
# \hline
# \end{tabular}

# %%
# print(tabulate(rows))

# %%
A = base.get_config()

# %%
base.updates
# Out:
# {'self': INLINE_TIMED_SAE_RUN:3ds_ae_e-c12_d-s12_xa_210510-225710,
#  'both': INLINE_TIMED_SAE_RUN:3ds_model_xa-ae-both_210511-004641,
#  'dec': INLINE_TIMED_SAE_RUN:3ds_model_xa-ae-dec_210511-004543,
#  'enc': INLINE_TIMED_SAE_RUN:3ds_model_xa-ae-enc_210511-004541}

# %%
if dataset is None:
    dataset = base.get_dataset()
    len(dataset)

# %%
dataset.switch_to('extra')
len(dataset)
# Out:
# 153578

# %%
loader = dataset.get_loader(batch_size=128)
len(loader)
# Out:
# 1199

# %%
for r in base.updates.values():
    model = r.get_model().cpu()
# Out:
# Freezable_Hybrid_Autoencoder(
#   (encoder): MultiLayer(
#     (layers): ModuleList(
#       (0): ConvLayer(
#         residual=False
#         (conv): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (3): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (7): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): MLP(
#         (0): Flatten(start_dim=1, end_dim=-1)
#         (1): Linear(in_features=256, out_features=256, bias=True)
#         (2): ELU(alpha=1.0, inplace=True)
#         (3): Linear(in_features=256, out_features=128, bias=True)
#         (4): ELU(alpha=1.0, inplace=True)
#         (5): Linear(in_features=128, out_features=12, bias=True)
#       )
#     )
#   )
#   (decoder): StyleDecoder(
#     (layers): ModuleList(
#       (0): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (3): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (7): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (13): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (14): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (15): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (16): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (17): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (18): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (19): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (20): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (21): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (22): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (23): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlin): Sigmoid()
#       )
#     )
#   )
#   (criterion): BCELoss()
# )
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0
# )
# Number of model parameters: 1230415
# Loaded parameters from C:\Users\anwan\Documents\workspace\extrap\3ds_ae_e-c12_d-s12_xa_210510-225710\ckpt80000
# Freezable_Hybrid_Autoencoder(
#   (encoder): MultiLayer(
#     (layers): ModuleList(
#       (0): ConvLayer(
#         residual=False
#         (conv): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (3): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (7): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): MLP(
#         (0): Flatten(start_dim=1, end_dim=-1)
#         (1): Linear(in_features=256, out_features=256, bias=True)
#         (2): ELU(alpha=1.0, inplace=True)
#         (3): Linear(in_features=256, out_features=128, bias=True)
#         (4): ELU(alpha=1.0, inplace=True)
#         (5): Linear(in_features=128, out_features=12, bias=True)
#       )
#     )
#   )
#   (decoder): StyleDecoder(
#     (layers): ModuleList(
#       (0): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (3): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (7): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (13): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (14): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (15): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (16): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (17): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (18): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (19): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (20): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (21): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (22): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (23): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlin): Sigmoid()
#       )
#     )
#   )
#   (criterion): BCELoss()
# )
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0
# )
# Number of model parameters: 1230415
# Loaded parameters from C:\Users\anwan\Documents\workspace\extrap\3ds_model_xa-ae-both_210511-004641\ckpt20000
# Freezing encoder
# Freezable_Hybrid_Autoencoder(
#   (encoder): MultiLayer(
#     (layers): ModuleList(
#       (0): ConvLayer(
#         residual=False
#         (conv): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (3): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (7): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): MLP(
#         (0): Flatten(start_dim=1, end_dim=-1)
#         (1): Linear(in_features=256, out_features=256, bias=True)
#         (2): ELU(alpha=1.0, inplace=True)
#         (3): Linear(in_features=256, out_features=128, bias=True)
#         (4): ELU(alpha=1.0, inplace=True)
#         (5): Linear(in_features=128, out_features=12, bias=True)
#       )
#     )
#   )
#   (decoder): StyleDecoder(
#     (layers): ModuleList(
#       (0): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (3): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (7): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (13): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (14): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (15): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (16): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (17): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (18): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (19): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (20): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (21): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (22): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (23): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlin): Sigmoid()
#       )
#     )
#   )
#   (criterion): BCELoss()
# )
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0
# )
# Number of model parameters: 1230415
# Loaded parameters from C:\Users\anwan\Documents\workspace\extrap\3ds_model_xa-ae-dec_210511-004543\ckpt20000
# Freezing decoder
# Freezable_Hybrid_Autoencoder(
#   (encoder): MultiLayer(
#     (layers): ModuleList(
#       (0): ConvLayer(
#         residual=False
#         (conv): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (3): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (7): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): MLP(
#         (0): Flatten(start_dim=1, end_dim=-1)
#         (1): Linear(in_features=256, out_features=256, bias=True)
#         (2): ELU(alpha=1.0, inplace=True)
#         (3): Linear(in_features=256, out_features=128, bias=True)
#         (4): ELU(alpha=1.0, inplace=True)
#         (5): Linear(in_features=128, out_features=12, bias=True)
#       )
#     )
#   )
#   (decoder): StyleDecoder(
#     (layers): ModuleList(
#       (0): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (3): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (7): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (13): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (14): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (15): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (16): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (17): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (18): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (19): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (20): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (21): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (22): Affine_AdaIN(
#         (net): Normal_MLP(
#           (0): Linear(in_features=12, out_features=64, bias=True)
#           (1): ELU(alpha=1.0, inplace=True)
#           (2): Linear(in_features=64, out_features=128, bias=True)
#           (3): ELU(alpha=1.0, inplace=True)
#           (4): Linear(in_features=128, out_features=128, bias=True)
#         )
#       )
#       (23): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlin): Sigmoid()
#       )
#     )
#   )
#   (criterion): BCELoss()
# )
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0
# )
# Number of model parameters: 1230415
# Loaded parameters from C:\Users\anwan\Documents\workspace\extrap\3ds_model_xa-ae-enc_210511-004541\ckpt20000

# %%
# Out:
# ['self', 'both', 'dec', 'enc']

# %%
qs = {}
losses = {key: [] for key in mkeys}
for i, (X, *other) in tqdm(enumerate(loader), total=len(loader)):
    if i == 25:
        break
    for key, run in base.updates.items():
        model = run.get_model()
        with torch.no_grad():
            R, Q = model(X, ret_q=True)
            if isinstance(Q, distrib.Distribution):
                Q = Q.mean
            L = F.mse_loss(X, R, reduction='none').reshape(X.size(0),-1).mean(-1)
        losses[key].append(L)
        qs[key] = Q
#     break
# Out:
#   0%|          | 0/1199 [00:00<?, ?it/s]
# Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.

# %%
for key, ls in losses.items():
    losses[key] = torch.cat(ls)
len(losses)
# Out:
# 4

# %%
lats = torch.stack([qs[key] for key in mkeys])
lats.shape
# Out:
# torch.Size([4, 128, 12])

# %%
samples = torch.stack([losses[key] for key in mkeys])
samples.shape
# Out:
# torch.Size([4, 3200])

# %%
samples.quantile(0.75, dim=1).tolist()

# %%
util.plot_distribs(samples, cut=True);
plt.ylim(0,0.02);
plt.xticks(range(len(mkeys)),mkeys)
plt.ylabel('Reconstruction Loss (MSE)')
plt.tight_layout();
# if figure_dir is not None:
#     util.save_figure(f'{setting}_{mcat}_losses',root=figure_dir)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
samples.shape
# Out:
# torch.Size([4, 3200])

# %%
# Out:
# [0.006800592876970768,
#  0.00046432059025391936,
#  0.0006016419501975179,
#  0.004090030677616596]

# %%
dataset = None
setting = 'xa'
raw = '''AE	3ds_ae_e-c12_d-c12_xa_210424-022637	3ds_model_xa-ae-enc_210426-160409	3ds_model_xa-ae-dec_210426-160409	3ds_model_xa-ae-both_210426-160408
WAE	3ds_wae10_e-c12_d-c12_xa_210424-022636	3ds_model_xa-wae-enc_210426-160410	3ds_model_xa-wae-dec_210426-160409	3ds_model_xa-wae-both_210426-160409
VAE	3ds_vae1_e-c12_d-c12_xa_210424-022638	3ds_model_xa-vae-enc_210426-160409	3ds_model_xa-vae-dec_210426-160409	3ds_model_xa-vae-both_210426-160409
2VAE	3ds_vae2_e-c12_d-c12_xa_210424-022637	3ds_model_xa-vae2-enc_210426-160410	3ds_model_xa-vae2-dec_210426-160408	3ds_model_xa-vae2-both_210426-160409
SAE12	3ds_ae_e-c12_d-s12_xa_210424-022637	3ds_model_xa-s12-enc_210426-160409	3ds_model_xa-s12-dec_210426-160409	'''.split('\n')
df = pd.DataFrame([r.split('\t') for r in raw], columns=['Model', 'Original', 'Encoder', 'Decoder', 'Both'])
df
# Out:
#    Model                                Original  \
# 0     AE     3ds_ae_e-c12_d-c12_xa_210424-022637
# 1    WAE  3ds_wae10_e-c12_d-c12_xa_210424-022636
# 2    VAE   3ds_vae1_e-c12_d-c12_xa_210424-022638
# 3   2VAE   3ds_vae2_e-c12_d-c12_xa_210424-022637
# 4  SAE12     3ds_ae_e-c12_d-s12_xa_210424-022637
#
#                                Encoder                              Decoder  \
# 0    3ds_model_xa-ae-enc_210426-160409    3ds_model_xa-ae-dec_210426-160409
# 1   3ds_model_xa-wae-enc_210426-160410   3ds_model_xa-wae-dec_210426-160409
# 2   3ds_model_xa-vae-enc_210426-160409   3ds_model_xa-vae-dec_210426-160409
# 3  3ds_model_xa-vae2-enc_210426-160410  3ds_model_xa-vae2-dec_210426-160408
# 4   3ds_model_xa-s12-enc_210426-160409   3ds_model_xa-s12-dec_210426-160409
#
#                                    Both
# 0    3ds_model_xa-ae-both_210426-160408
# 1   3ds_model_xa-wae-both_210426-160409
# 2   3ds_model_xa-vae-both_210426-160409
# 3  3ds_model_xa-vae2-both_210426-160409
# 4

# %%
dataset = None
setting = 'xas'
raw = '''AE	3ds_ae_e-c12_d-c12_xas_210424-022530	3ds_model_xas-ae-enc_210426-160409	3ds_model_xas-ae-dec_210426-160409	3ds_model_xas-ae-both_210426-160409
WAE	3ds_wae10_e-c12_d-c12_xas_210424-022529	3ds_model_xas-wae-enc_210426-160409	3ds_model_xas-wae-dec_210426-160409	3ds_model_xas-wae-both_210426-160407
VAE	3ds_vae1_e-c12_d-c12_xas_210424-022530	3ds_model_xas-vae-enc_210426-160409	3ds_model_xas-vae-dec_210426-160409	3ds_model_xas-vae-both_210426-160409
2VAE	3ds_vae2_e-c12_d-c12_xas_210424-022528	3ds_model_xas-vae2-enc_210426-160408	3ds_model_xas-vae2-dec_210426-160408	3ds_model_xas-vae2-both_210426-160409
SAE12	3ds_ae_e-c12_d-s12_xas_210424-022530	3ds_model_xas-s12-enc_210426-160407	3ds_model_xas-s12-dec_210426-160408	3ds_model_xas-s12-both_210426-160410'''.split('\n')
df = pd.DataFrame([r.split('\t') for r in raw], columns=['Model', 'Original', 'Encoder', 'Decoder', 'Both'])
df
# Out:
#    Model                                 Original  \
# 0     AE     3ds_ae_e-c12_d-c12_xas_210424-022530
# 1    WAE  3ds_wae10_e-c12_d-c12_xas_210424-022529
# 2    VAE   3ds_vae1_e-c12_d-c12_xas_210424-022530
# 3   2VAE   3ds_vae2_e-c12_d-c12_xas_210424-022528
# 4  SAE12     3ds_ae_e-c12_d-s12_xas_210424-022530
#
#                                 Encoder                               Decoder  \
# 0    3ds_model_xas-ae-enc_210426-160409    3ds_model_xas-ae-dec_210426-160409
# 1   3ds_model_xas-wae-enc_210426-160409   3ds_model_xas-wae-dec_210426-160409
# 2   3ds_model_xas-vae-enc_210426-160409   3ds_model_xas-vae-dec_210426-160409
# 3  3ds_model_xas-vae2-enc_210426-160408  3ds_model_xas-vae2-dec_210426-160408
# 4   3ds_model_xas-s12-enc_210426-160407   3ds_model_xas-s12-dec_210426-160408
#
#                                     Both
# 0    3ds_model_xas-ae-both_210426-160409
# 1   3ds_model_xas-wae-both_210426-160407
# 2   3ds_model_xas-vae-both_210426-160409
# 3  3ds_model_xas-vae2-both_210426-160409
# 4   3ds_model_xas-s12-both_210426-160410

# %%
mcat = 'SAE12'
# mcat = 'VAE'
# mcat = 'AE'
mcat = '2VAE'
# mcat = 'WAE'

minfo = df[df['Model'] == mcat].to_dict()
minfo = {k: next(iter(v.values())) for k,v in minfo.items()}
minfo = {k: v for k,v in minfo.items() if v is not None and len(v)}
mname = minfo['Model']
del minfo['Model']
mname, minfo
# Out:
# ('2VAE',
#  {'Original': '3ds_vae2_e-c12_d-c12_xa_210424-022637',
#   'Encoder': '3ds_model_xa-vae2-enc_210426-160410',
#   'Decoder': '3ds_model_xa-vae2-dec_210426-160408',
#   'Both': '3ds_model_xa-vae2-both_210426-160409'})

# %%
mkeys = list(minfo)
mkeys
# Out:
# ['Original', 'Encoder', 'Decoder', 'Both']

# %%
runs = {k: fig.quick_run('load-run', path=v, root=str(root), **{'override.legacy':True, 'override.root': str(root)}) for k,v in minfo.items()}
len(runs)
# Out:
# | path: '3ds_vae2_e-c12_d-c12_xa_210424-022637'
# | saveroot: None (by default)
# | root: 'C:\\Users\\anwan\\Documents\\workspace\\exts'
# | [Pushed] path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637'
# | run: [<class 'omnifig.config.ConfigDict'>]
# | CREATING . (type=sae-run) (mod={'inline': 5, 'timed-run': 1})
# |  > silent: None (by default)
# |  > invisible: False (by default)
# |  > use_config_root: True (by default)
# |  > .path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637'
# |  > [Pushed] path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637'
# |  > ckpt-num: None (by default)
# |  > best: False (by default)
# |  > last: True (by default)
# |  > [Pushed] dataset._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637\\ckpt80000'
# |  > [Pushed] model._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637\\ckpt80000'
# |  > [Pushed] records._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637\\ckpt80000'
# |  > [Pushed] clock._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637\\ckpt80000'
# |  > CREATING clock (type=clock)
# |  >  > CREATING .stats (type=stats-manager)
# |  >  >  > stat-collection-fmts: {} (by default)
# |  >  >  > reset-modes [list with 2 item/s]
# |  >  >  >  > (0): 'val'
# |  >  >  >  > (1): 'test'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > meter-info: [<class 'omnifig.config.ConfigDict'>]
# |  >  > stats-fmt: None (by default)
# |  >  > smooth-tau --> tau: 1
# |  >  > limit: None (by default)
# |  >  > skip_load: False (by default)
# |  >  > _load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637\\ckpt80000'
# |  >  > timed-fmt: 'time-{}' (by default)
# |  > CREATING . (type=records)
# |  >  > include_zero: False (by default)
# |  >  > freq: 200
# |  >  > mode: 'train' (by default)
# |  >  > .seed: 0
# |  >  > _history: None (by default)
# |  >  > REUSING .stats (type=stats-manager): id=0x1719f30eca8
# |  >  > CREATING .logger (type=logger)
# |  >  >  > log_dir --> .path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637'
# |  >  >  > tensorboard: True
# |  >  >  > txt: False (by default)
# |  >  >  > logfile: None (by default)
# |  >  >  > kwargs: {} (by default)
# |  >  > use_log_fmts: True (by default)
# |  >  > stats_format: 'json' (by default)
# |  >  > info_format: 'yaml' (by default)
# |  >  > log-smooth: True (by default)
# |  >  > log-model-str: True (by default)
# |  > inline: False (by default)
# |  > pbar: None (by default)
# | path: '3ds_model_xa-vae2-enc_210426-160410'
# | saveroot: None (by default)
# | root: 'C:\\Users\\anwan\\Documents\\workspace\\exts'
# | [Pushed] path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410'
# | run: [<class 'omnifig.config.ConfigDict'>]
# | CREATING . (type=sae-run) (mod={'inline': 5, 'timed-run': 1})
# |  > silent: None (by default)
# |  > invisible: False (by default)
# |  > use_config_root: True (by default)
# |  > .path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410'
# |  > [Pushed] path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410'
# |  > ckpt-num: None (by default)
# |  > best: False (by default)
# |  > last: True (by default)
# |  > [Pushed] dataset._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410\\ckpt20000'
# |  > [Pushed] model._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410\\ckpt20000'
# |  > [Pushed] records._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410\\ckpt20000'
# |  > [Pushed] clock._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410\\ckpt20000'
# |  > CREATING clock (type=clock)
# |  >  > CREATING .stats (type=stats-manager)
# |  >  >  > stat-collection-fmts: {} (by default)
# |  >  >  > reset-modes [list with 2 item/s]
# |  >  >  >  > (0): 'val'
# |  >  >  >  > (1): 'test'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > meter-info: [<class 'omnifig.config.ConfigDict'>]
# |  >  > stats-fmt: None (by default)
# |  >  > smooth-tau --> tau: 1
# |  >  > limit: None (by default)
# |  >  > skip_load: False (by default)
# |  >  > _load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410\\ckpt20000'
# |  >  > timed-fmt: 'time-{}' (by default)
# |  > CREATING . (type=records)
# |  >  > include_zero: False (by default)
# |  >  > freq: 200
# |  >  > mode: 'train' (by default)
# |  >  > .seed: 0
# |  >  > _history: None (by default)
# |  >  > REUSING .stats (type=stats-manager): id=0x171a7f674c8
# |  >  > CREATING .logger (type=logger)
# |  >  >  > log_dir --> .path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410'
# |  >  >  > tensorboard: True
# |  >  >  > txt: False (by default)
# |  >  >  > logfile: None (by default)
# |  >  >  > kwargs: {} (by default)
# |  >  > use_log_fmts: True (by default)
# |  >  > stats_format: 'json' (by default)
# |  >  > info_format: 'yaml' (by default)
# |  >  > log-smooth: True (by default)
# |  >  > log-model-str: True (by default)
# |  > inline: False (by default)
# |  > pbar: None (by default)
# | path: '3ds_model_xa-vae2-dec_210426-160408'
# | saveroot: None (by default)
# | root: 'C:\\Users\\anwan\\Documents\\workspace\\exts'
# | [Pushed] path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-dec_210426-160408'
# | run: [<class 'omnifig.config.ConfigDict'>]
# | CREATING . (type=sae-run) (mod={'inline': 5, 'timed-run': 1})
# |  > silent: None (by default)
# |  > invisible: False (by default)
# |  > use_config_root: True (by default)
# |  > .path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-dec_210426-160408'
# |  > [Pushed] path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-dec_210426-160408'
# |  > ckpt-num: None (by default)
# |  > best: False (by default)
# |  > last: True (by default)
# |  > [Pushed] dataset._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-dec_210426-160408\\ckpt20000'
# |  > [Pushed] model._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-dec_210426-160408\\ckpt20000'
# |  > [Pushed] records._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-dec_210426-160408\\ckpt20000'
# |  > [Pushed] clock._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-dec_210426-160408\\ckpt20000'
# |  > CREATING clock (type=clock)
# |  >  > CREATING .stats (type=stats-manager)
# |  >  >  > stat-collection-fmts: {} (by default)
# |  >  >  > reset-modes [list with 2 item/s]
# |  >  >  >  > (0): 'val'
# |  >  >  >  > (1): 'test'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > meter-info: [<class 'omnifig.config.ConfigDict'>]
# |  >  > stats-fmt: None (by default)
# |  >  > smooth-tau --> tau: 1
# |  >  > limit: None (by default)
# |  >  > skip_load: False (by default)
# |  >  > _load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-dec_210426-160408\\ckpt20000'
# |  >  > timed-fmt: 'time-{}' (by default)
# |  > CREATING . (type=records)
# |  >  > include_zero: False (by default)
# |  >  > freq: 200
# |  >  > mode: 'train' (by default)
# |  >  > .seed: 0
# |  >  > _history: None (by default)
# |  >  > REUSING .stats (type=stats-manager): id=0x1728a2e8168
# |  >  > CREATING .logger (type=logger)
# |  >  >  > log_dir --> .path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-dec_210426-160408'
# |  >  >  > tensorboard: True
# |  >  >  > txt: False (by default)
# |  >  >  > logfile: None (by default)
# |  >  >  > kwargs: {} (by default)
# |  >  > use_log_fmts: True (by default)
# |  >  > stats_format: 'json' (by default)
# |  >  > info_format: 'yaml' (by default)
# |  >  > log-smooth: True (by default)
# |  >  > log-model-str: True (by default)
# |  > inline: False (by default)
# |  > pbar: None (by default)
# | path: '3ds_model_xa-vae2-both_210426-160409'
# | saveroot: None (by default)
# | root: 'C:\\Users\\anwan\\Documents\\workspace\\exts'
# | [Pushed] path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-both_210426-160409'
# | run: [<class 'omnifig.config.ConfigDict'>]
# | CREATING . (type=sae-run) (mod={'inline': 5, 'timed-run': 1})
# |  > silent: None (by default)
# |  > invisible: False (by default)
# |  > use_config_root: True (by default)
# |  > .path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-both_210426-160409'
# |  > [Pushed] path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-both_210426-160409'
# |  > ckpt-num: None (by default)
# |  > best: False (by default)
# |  > last: True (by default)
# |  > [Pushed] dataset._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-both_210426-160409\\ckpt20000'
# |  > [Pushed] model._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-both_210426-160409\\ckpt20000'
# |  > [Pushed] records._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-both_210426-160409\\ckpt20000'
# |  > [Pushed] clock._load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-both_210426-160409\\ckpt20000'
# |  > CREATING clock (type=clock)
# |  >  > CREATING .stats (type=stats-manager)
# |  >  >  > stat-collection-fmts: {} (by default)
# |  >  >  > reset-modes [list with 2 item/s]
# |  >  >  >  > (0): 'val'
# |  >  >  >  > (1): 'test'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > meter-info: [<class 'omnifig.config.ConfigDict'>]
# |  >  > stats-fmt: None (by default)
# |  >  > smooth-tau --> tau: 1
# |  >  > limit: None (by default)
# |  >  > skip_load: False (by default)
# |  >  > _load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-both_210426-160409\\ckpt20000'
# |  >  > timed-fmt: 'time-{}' (by default)
# |  > CREATING . (type=records)
# |  >  > include_zero: False (by default)
# |  >  > freq: 200
# |  >  > mode: 'train' (by default)
# |  >  > .seed: 0
# |  >  > _history: None (by default)
# |  >  > REUSING .stats (type=stats-manager): id=0x1728a2d33a8
# |  >  > CREATING .logger (type=logger)
# |  >  >  > log_dir --> .path: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-both_210426-160409'
# |  >  >  > tensorboard: True
# |  >  >  > txt: False (by default)
# |  >  >  > logfile: None (by default)
# |  >  >  > kwargs: {} (by default)
# |  >  > use_log_fmts: True (by default)
# |  >  > stats_format: 'json' (by default)
# |  >  > info_format: 'yaml' (by default)
# |  >  > log-smooth: True (by default)
# |  >  > log-model-str: True (by default)
# |  > inline: False (by default)
# |  > pbar: None (by default)
# 4

# %%
run = runs['Original']

# %%
if dataset is None:
    dataset = run.get_dataset()
    len(dataset)

# %%
dataset.switch_to('extra')
len(dataset)
# Out:
# 102271

# %%
# X, = dataset.get_batch(batch_size=64)
# X.shape

# %%
# util.plot_imgs(X);

# %%
# with torch.no_grad():
#     R, Q = model(X, ret_q=True)
#     if isinstance(Q, distrib.Distribution):
#         Q = Q.mean
# R.shape, Q.shape

# %%
# util.plot_imgs(R);

# %%
for run in runs.values():
    model = run.get_model()
# Out:
# | CREATING . (type=model)
# |  > .legacy: True
# |  > _load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_vae2_e-c12_d-c12_xa_210424-022637\\ckpt80000'
# |  > load-model: None (by default)
# |  > model._model_mod [dict with 2 item/s]
# |  >  > (freezable): 8
# |  >  > (hybrid): 1
# |  > .seed: 0
# |  > CREATING model (type=vae) (mod={'freezable': 8, 'hybrid': 1})
# |  >  > freeze-encoder: False (by default)
# |  >  > freeze-decoder: False (by default)
# |  >  > viz-gen-hybrid: True (by default)
# |  >  > viz-gen-prior: True (by default)
# |  >  > [Pushed] reg: None
# |  >  > CREATING encoder (type=multilayer) (mod={'normal': 1})
# |  >  >  > change-dout: True (by default)
# |  >  >  > _dout_key: 'latent-dim'
# |  >  >  > ..latent-dim: 12
# |  >  >  > _din --> ..din [list with 3 item/s]
# |  >  >  >  > (0): 3
# |  >  >  >  > (1): 64
# |  >  >  >  > (2): 64
# |  >  >  > _dout --> latent-dim: 24
# |  >  >  > in_order: True (by default)
# |  >  >  > first: [<class 'omnifig.config.ConfigDict'>]
# |  >  >  > CREATING . (type=conv-layer)
# |  >  >  >  > in-shape --> din: (3, 64, 64)
# |  >  >  >  > ..channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > .pool: 'max'
# |  >  >  >  > kernel_size --> kernel: 5
# |  >  >  >  > padding: 2 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ..norm: 'group'
# |  >  >  >  > ..nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ...device: 'cuda'
# |  >  >  > ITERATOR layers [list with 11 item/s]
# |  >  >  > CREATING 0 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 32, 32)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 1 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 32, 32)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 2 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 32, 32)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > ..pool: 'max'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 3 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 16, 16)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 4 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 16, 16)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 5 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 16, 16)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > ..pool: 'max'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 6 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 8, 8)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 7 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 8, 8)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 8 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 8, 8)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > ..pool: 'max'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 9 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 4, 4)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 10 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 4, 4)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > ..pool: 'max'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > last: [<class 'omnifig.config.ConfigDict'>]
# |  >  >  > CREATING . (type=mlp)
# |  >  >  >  > _din --> din: (64, 2, 2)
# |  >  >  >  > _dout --> dout: 24
# |  >  >  >  > hidden_dims --> hidden_fc --> hidden [list with 2 item/s]
# |  >  >  >  >  > (0): 256
# |  >  >  >  >  > (1): 128
# |  >  >  >  > initializer: None (by default)
# |  >  >  >  > ..nonlin: 'elu'
# |  >  >  >  > output_nonlin --> out_nonlin: None
# |  >  >  >  > bias: True (by default)
# |  >  >  >  > output_bias --> out_bias: None (by default)
# |  >  >  >  > make_kwargs: {} (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ...device: 'cuda'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > ..device: 'cuda'
# |  >  > CREATING decoder (type=multilayer)
# |  >  >  > _din --> ..latent-dim: 12
# |  >  >  > _dout --> ..dout [list with 3 item/s]
# |  >  >  >  > (0): 3
# |  >  >  >  > (1): 64
# |  >  >  >  > (2): 64
# |  >  >  > in_order: False
# |  >  >  > last: [<class 'omnifig.config.ConfigDict'>]
# |  >  >  > CREATING . (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ..channels: 64
# |  >  >  >  > out-shape --> dout: (3, 64, 64)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > .unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > norm: None
# |  >  >  >  > nonlin: 'sigmoid'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ...device: 'cuda'
# |  >  >  > ITERATOR layers [list with 11 item/s]
# |  >  >  > CREATING 10 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 32, 32)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 9 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 32, 32)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 8 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 16, 16)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 7 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 16, 16)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 6 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 16, 16)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 5 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 8, 8)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 4 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 8, 8)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 3 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 8, 8)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 2 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 4, 4)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 1 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 4, 4)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 0 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 2, 2)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > first: [<class 'omnifig.config.ConfigDict'>]
# |  >  >  > CREATING . (type=mlp)
# |  >  >  >  > _din --> din: 12
# |  >  >  >  > _dout --> dout: (64, 2, 2)
# |  >  >  >  > hidden_dims --> hidden_fc --> hidden [list with 2 item/s]
# |  >  >  >  >  > (0): 128
# |  >  >  >  >  > (1): 256
# |  >  >  >  > initializer: None (by default)
# |  >  >  >  > ..nonlin: 'elu'
# |  >  >  >  > output_nonlin --> out_nonlin: None (by default)
# |  >  >  >  > bias: True (by default)
# |  >  >  >  > output_bias --> out_bias: None (by default)
# |  >  >  >  > make_kwargs: {} (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ...device: 'cuda'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > ..device: 'cuda'
# |  >  > .reg-wt: 2
# |  >  > reg: None
# |  >  > CREATING criterion (type=criterion)
# |  >  >  > ident: 'bce'
# |  >  >  > kwargs [dict with 1 item/s]
# |  >  >  >  > (reduction): 'sum'
# |  >  > viz-latent: True (by default)
# |  >  > viz-rec: True (by default)
# |  >  > viz-enc: True (by default)
# |  >  > viz-dec: True (by default)
# |  >  > .seed: 0
# |  >  > strict_load_state: True (by default)
# |  >  > optim-metric: 'loss' (by default)
# |  >  > CREATING .stats (type=stats-manager)
# |  >  >  > stat-collection-fmts: {} (by default)
# |  >  >  > reset-modes [list with 2 item/s]
# |  >  >  >  > (0): 'val'
# |  >  >  >  > (1): 'test'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > meter-info: [<class 'omnifig.config.ConfigDict'>]
# |  >  > stats-fmt: None (by default)
# |  >  > smooth-tau --> tau: None (by default)
# |  >  > mode: 'train' (by default)
# |  >  > .device: 'cuda'
# |  >  > force-viz: False (by default)
# |  >  > hybridize-groups: False (by default)
# |  > CREATING optim (type=adam)
# |  >  > lr: 0.0005
# |  >  > beta1: 0.9
# |  >  > beta2: 0.999
# |  >  > eps: 1e-08 (by default)
# |  >  > weight_decay: 0
# |  >  > amsgrad: False (by default)
# |  > _print_model: True
# Freezable_Hybrid_VAE(
#   (encoder): Normal_MultiLayer(
#     (layers): ModuleList(
#       (0): ConvLayer(
#         residual=False
#         (conv): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (3): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (7): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): MLP(
#         (0): Flatten(start_dim=1, end_dim=-1)
#         (1): Linear(in_features=256, out_features=256, bias=True)
#         (2): ELU(alpha=1.0, inplace=True)
#         (3): Linear(in_features=256, out_features=128, bias=True)
#         (4): ELU(alpha=1.0, inplace=True)
#         (5): Linear(in_features=128, out_features=24, bias=True)
#       )
#     )
#   )
#   (decoder): MultiLayer(
#     (layers): ModuleList(
#       (0): MLP(
#         (0): Linear(in_features=12, out_features=128, bias=True)
#         (1): ELU(alpha=1.0, inplace=True)
#         (2): Linear(in_features=128, out_features=256, bias=True)
#         (3): ELU(alpha=1.0, inplace=True)
#         (4): Linear(in_features=256, out_features=256, bias=True)
#         (5): Reshaper(out=(64, 2, 2))
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (3): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (7): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlin): Sigmoid()
#       )
#     )
#   )
#   (criterion): BCELoss()
# )
# |  > _print_optim: True
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
# Number of model parameters: 1024219
# Loaded parameters from C:\Users\anwan\Documents\workspace\exts\3ds_vae2_e-c12_d-c12_xa_210424-022637\ckpt80000
# | CREATING . (type=model)
# |  > .legacy: True
# |  > _load-ckpt: 'C:\\Users\\anwan\\Documents\\workspace\\exts\\3ds_model_xa-vae2-enc_210426-160410\\ckpt20000'
# |  > .load-model: '3ds_vae2_e-c12_d-c12_xa_210424-022637'
# |  > model._model_mod [dict with 2 item/s]
# |  >  > (freezable): 8
# |  >  > (hybrid): 1
# |  > .seed: 0
# |  > CREATING model (type=vae) (mod={'freezable': 8, 'hybrid': 1})
# |  >  > freeze-encoder: False (by default)
# |  >  > .freeze-decoder: True
# |  >  > viz-gen-hybrid: True (by default)
# |  >  > viz-gen-prior: True (by default)
# |  >  > [Pushed] reg: None
# |  >  > CREATING encoder (type=multilayer) (mod={'normal': 1})
# |  >  >  > change-dout: True (by default)
# |  >  >  > _dout_key: 'latent-dim'
# |  >  >  > ..latent-dim: 12
# |  >  >  > _din --> ..din [list with 3 item/s]
# |  >  >  >  > (0): 3
# |  >  >  >  > (1): 64
# |  >  >  >  > (2): 64
# |  >  >  > _dout --> latent-dim: 24
# |  >  >  > in_order: True (by default)
# |  >  >  > first: [<class 'omnifig.config.ConfigDict'>]
# |  >  >  > CREATING . (type=conv-layer)
# |  >  >  >  > in-shape --> din: (3, 64, 64)
# |  >  >  >  > ..channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > .pool: 'max'
# |  >  >  >  > kernel_size --> kernel: 5
# |  >  >  >  > padding: 2 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ..norm: 'group'
# |  >  >  >  > ..nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ...device: 'cuda'
# |  >  >  > ITERATOR layers [list with 11 item/s]
# |  >  >  > CREATING 0 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 32, 32)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 1 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 32, 32)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 2 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 32, 32)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > ..pool: 'max'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 3 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 16, 16)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 4 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 16, 16)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 5 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 16, 16)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > ..pool: 'max'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 6 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 8, 8)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 7 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 8, 8)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 8 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 8, 8)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > ..pool: 'max'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 9 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 4, 4)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > ..down: 1
# |  >  >  >  > up: None (by default)
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 10 (type=conv-layer)
# |  >  >  >  > in-shape --> din: (64, 4, 4)
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: None
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: 2
# |  >  >  >  > up: None (by default)
# |  >  >  >  > ..pool: 'max'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > last: [<class 'omnifig.config.ConfigDict'>]
# |  >  >  > CREATING . (type=mlp)
# |  >  >  >  > _din --> din: (64, 2, 2)
# |  >  >  >  > _dout --> dout: 24
# |  >  >  >  > hidden_dims --> hidden_fc --> hidden [list with 2 item/s]
# |  >  >  >  >  > (0): 256
# |  >  >  >  >  > (1): 128
# |  >  >  >  > initializer: None (by default)
# |  >  >  >  > ..nonlin: 'elu'
# |  >  >  >  > output_nonlin --> out_nonlin: None
# |  >  >  >  > bias: True (by default)
# |  >  >  >  > output_bias --> out_bias: None (by default)
# |  >  >  >  > make_kwargs: {} (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ...device: 'cuda'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > ..device: 'cuda'
# |  >  > CREATING decoder (type=multilayer)
# |  >  >  > _din --> ..latent-dim: 12
# |  >  >  > _dout --> ..dout [list with 3 item/s]
# |  >  >  >  > (0): 3
# |  >  >  >  > (1): 64
# |  >  >  >  > (2): 64
# |  >  >  > in_order: False
# |  >  >  > last: [<class 'omnifig.config.ConfigDict'>]
# |  >  >  > CREATING . (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ..channels: 64
# |  >  >  >  > out-shape --> dout: (3, 64, 64)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > .unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > norm: None
# |  >  >  >  > nonlin: 'sigmoid'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ...device: 'cuda'
# |  >  >  > ITERATOR layers [list with 11 item/s]
# |  >  >  > CREATING 10 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 32, 32)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 9 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 32, 32)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 8 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 16, 16)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 7 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 16, 16)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 6 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 16, 16)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 5 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 8, 8)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 4 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 8, 8)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 3 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 8, 8)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 2 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 4, 4)
# |  >  >  >  > transpose: None (by default)
# ...
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 7 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 16, 16)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 6 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 16, 16)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 5 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 8, 8)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 4 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 8, 8)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 3 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 8, 8)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 2 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 4, 4)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 1 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 4, 4)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > up: 2
# |  >  >  >  > ..unpool: 'bilinear'
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > CREATING 0 (type=conv-layer)
# |  >  >  >  > in-shape --> din: None
# |  >  >  >  > ...channels: 64
# |  >  >  >  > out-shape --> dout: (64, 2, 2)
# |  >  >  >  > transpose: None (by default)
# |  >  >  >  > down: None (by default)
# |  >  >  >  > ..up: 1
# |  >  >  >  > kernel_size --> kernel: (3, 3) (by default)
# |  >  >  >  > padding: 1 (by default)
# |  >  >  >  > dilation: (1, 1) (by default)
# |  >  >  >  > stride: (1, 1) (by default)
# |  >  >  >  > ...norm: 'group'
# |  >  >  >  > ...nonlin: 'elu'
# |  >  >  >  > conv_kwargs: {} (by default)
# |  >  >  >  > residual: False (by default)
# |  >  >  >  > force_res: False (by default)
# |  >  >  >  > print_dims: False (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ....device: 'cuda'
# |  >  >  > first: [<class 'omnifig.config.ConfigDict'>]
# |  >  >  > CREATING . (type=mlp)
# |  >  >  >  > _din --> din: 12
# |  >  >  >  > _dout --> dout: (64, 2, 2)
# |  >  >  >  > hidden_dims --> hidden_fc --> hidden [list with 2 item/s]
# |  >  >  >  >  > (0): 128
# |  >  >  >  >  > (1): 256
# |  >  >  >  > initializer: None (by default)
# |  >  >  >  > ..nonlin: 'elu'
# |  >  >  >  > output_nonlin --> out_nonlin: None (by default)
# |  >  >  >  > bias: True (by default)
# |  >  >  >  > output_bias --> out_bias: None (by default)
# |  >  >  >  > make_kwargs: {} (by default)
# |  >  >  >  > mode: 'train' (by default)
# |  >  >  >  > ...device: 'cuda'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > ..device: 'cuda'
# |  >  > .reg-wt: 2
# |  >  > reg: None
# |  >  > CREATING criterion (type=criterion)
# |  >  >  > ident: 'bce'
# |  >  >  > kwargs [dict with 1 item/s]
# |  >  >  >  > (reduction): 'sum'
# |  >  > viz-latent: True (by default)
# |  >  > viz-rec: True (by default)
# |  >  > viz-enc: True (by default)
# |  >  > viz-dec: True (by default)
# |  >  > .seed: 0
# |  >  > strict_load_state: True (by default)
# |  >  > optim-metric: 'loss' (by default)
# |  >  > CREATING .stats (type=stats-manager)
# |  >  >  > stat-collection-fmts: {} (by default)
# |  >  >  > reset-modes [list with 2 item/s]
# |  >  >  >  > (0): 'val'
# |  >  >  >  > (1): 'test'
# |  >  >  > mode: 'train' (by default)
# |  >  >  > meter-info: [<class 'omnifig.config.ConfigDict'>]
# |  >  > stats-fmt: None (by default)
# |  >  > smooth-tau --> tau: None (by default)
# |  >  > mode: 'train' (by default)
# |  >  > .device: 'cuda'
# |  >  > force-viz: False (by default)
# |  >  > hybridize-groups: False (by default)
# |  > CREATING optim (type=adam)
# |  >  > lr: 0.0005
# |  >  > beta1: 0.9
# |  >  > beta2: 0.999
# |  >  > eps: 1e-08 (by default)
# |  >  > weight_decay: 0
# |  >  > amsgrad: False (by default)
# |  > _print_model: True
# Freezable_Hybrid_VAE(
#   (encoder): Normal_MultiLayer(
#     (layers): ModuleList(
#       (0): ConvLayer(
#         residual=False
#         (conv): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (3): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (7): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): MLP(
#         (0): Flatten(start_dim=1, end_dim=-1)
#         (1): Linear(in_features=256, out_features=256, bias=True)
#         (2): ELU(alpha=1.0, inplace=True)
#         (3): Linear(in_features=256, out_features=128, bias=True)
#         (4): ELU(alpha=1.0, inplace=True)
#         (5): Linear(in_features=128, out_features=24, bias=True)
#       )
#     )
#   )
#   (decoder): MultiLayer(
#     (layers): ModuleList(
#       (0): MLP(
#         (0): Linear(in_features=12, out_features=128, bias=True)
#         (1): ELU(alpha=1.0, inplace=True)
#         (2): Linear(in_features=128, out_features=256, bias=True)
#         (3): ELU(alpha=1.0, inplace=True)
#         (4): Linear(in_features=256, out_features=256, bias=True)
#         (5): Reshaper(out=(64, 2, 2))
#       )
#       (1): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (2): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (3): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (4): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (5): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (6): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (7): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (8): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (9): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (10): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (11): ConvLayer(
#         residual=False
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (nonlin): ELU(alpha=1.0, inplace=True)
#       )
#       (12): ConvLayer(
#         residual=False
#         (unpool): Upsample(scale_factor=(2.0, 2.0), mode=bilinear)
#         (conv): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlin): Sigmoid()
#       )
#     )
#   )
#   (criterion): BCELoss()
# )
# |  > _print_optim: True
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
# Number of model parameters: 1024219
# Loaded parameters from C:\Users\anwan\Documents\workspace\exts\3ds_model_xa-vae2-both_210426-160409\ckpt20000

# %%
# imgs = sampler.full_intervention(intervention_dim)
# imgs.shape

# %%
# recs = {}
# for key, run in runs.items():
#     model = run.get_model()
#     with torch.no_grad():
#         rec = model(imgs.to(device))
#         rec = rec.permute(1,2,0,3).reshape(3, 64, -1).cpu() 
#         recs[key] = rec
# seqs = torch.stack([imgs.permute(1,2,0,3).reshape(3, 64, -1).cpu()] + [recs[k] for k in mkeys])
# util.plot_imgs(seqs, H=len(recs)+1);
# if figure_dir is not None:
#     util.save_figure(f'{setting}_{mcat}',root=figure_dir)

# %%
loader = dataset.get_loader(batch_size=128)
len(loader)
# Out:
# 798

# %%
qs = {}
losses = {key: [] for key in mkeys}
for i, (X, *other) in tqdm(enumerate(loader), total=len(loader)):
    if i == 25:
        break
    for key, run in runs.items():
        model = run.get_model()
        with torch.no_grad():
            R, Q = model(X, ret_q=True)
            if isinstance(Q, distrib.Distribution):
                Q = Q.mean
            L = F.mse_loss(X, R, reduction='none').reshape(X.size(0),-1).mean(-1)
        losses[key].append(L)
        qs[key] = Q
    break
# Out:
# This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/798 [00:00<?, ?it/s]
# Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.

# %%
for key, ls in losses.items():
    losses[key] = torch.cat(ls)
len(losses)
# Out:
# 4

# %%
lats = torch.stack([qs[key] for key in mkeys])
lats.shape
# Out:
# torch.Size([4, 128, 12])

# %%
samples = torch.stack([losses[key] for key in mkeys])
samples.shape
# Out:
# torch.Size([4, 128])

# %%
util.plot_distribs(samples, cut=True);
plt.ylim(0,0.02);
plt.xticks(range(len(mkeys)),mkeys)
plt.ylabel('Reconstruction Loss (MSE)')
plt.tight_layout();
# if figure_dir is not None:
#     util.save_figure(f'{setting}_{mcat}_losses',root=figure_dir)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
model = runs['Original'].get_model()

# %%
fullQ = []
total = 10000
bs = 100
loader = dataset2.get_loader(infinite=True, shuffle=True, seed=0, batch_size=bs)
loader = iter(loader)
pbar = tqdm(total=total)
while len(fullQ) < total//bs:
    batch = next(loader)
    x = model._process_batch(batch).original
    with torch.no_grad():
        q = model.encode(x)
        if isinstance(q, distrib.Distribution):
            q = q.loc
        fullQ.append(q)
    pbar.update(bs)
del loader
fullQ = torch.cat(fullQ)
fullQ.shape
# Out:
# This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/10000 [00:00<?, ?it/s]
# torch.Size([10000, 12])

# %%
scales = fullQ.std(0)
# scales = None

# %%
mats, lts = factor_reponses(model.encode, model.decode, interventions, pbar=tqdm, include_q=True, 
                       resp_kwargs=dict(scales=scales,force_different=True))
# W = mats.mean(-1).mean(1)

M = mats.min(1)[0].max(-1)[0]
# M = mats.mean(1).max(-1)[0]

mats.shape, len(lts), M.shape
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# (torch.Size([6, 20, 12, 12]), 6, torch.Size([6, 12]))

# %%
util.plot_mat(M, val_fmt=1)
plt.yticks(range(len(factors)), factors)
plt.xlabel('Latent dimension')
plt.tight_layout()
# util.save_figure(f'{run_name}_factor-responses', root=figure_dir)
util.save_figure(f'{setting}_{mname}_factor-responses', root=figure_dir)
pass # an intervention on which latent dimension responds the most given that the intervention can 
#      only change the given factor of variation
# Out:
# <img src="data:image/png;base64,..." width="640">
# Figure xa_2VAE_factor-responses saved as {'png'}

# %%
# xas
dim = 1 # SAE
dim = 9 # 2VAE
# dim = 6

# xa
dim = 2 # sae
dim = 0 # 2vae

# %%
# vals = lats[...,dim]
# util.plot_hists(vals.cpu().detach());

# %%
vals = lats[...,dim]
util.plot_distribs(vals);
plt.xticks(range(len(mkeys)),mkeys)
plt.ylabel(f'Dimension {dim} Marginal')
util.save_figure(f'{setting}_{mname}_1d-latent-changes_dim{dim}', root=figure_dir)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0, 0.5, 'Dimension 2 Marginal')

# %%
util.plot_imgs(starter[:60])
# Out:
# <img src="data:image/png;base64,..." width="800">
# (<Figure size 800x480 with 60 Axes>, <numpy.flatiter at 0x2b4bb90c450>)

# %%
idx = 18 # xa
idx = 27 # xas

# %%
recs.keys()
# Out:
# dict_keys(['SAE12', 'SAE6', 'LVAE12', 'VAE1', 'VAE4', 'AdaAE12', 'AE', 'WAE'])

# %%
sel = ['SAE12', 'LVAE12', 'VAE4', 'AdaAE12']

# %%
ims = torch.cat([torch.stack([starter[idx].cpu()] + [recs[s][k][idx] for k in mkeys]) for s in sel])
ims.shape
# Out:
# torch.Size([20, 3, 64, 64])

# %%
util.plot_imgs(ims, H=4);
# Out:
# <img src="data:image/png;base64,..." width="599.3333333333334">

# %%
H, W = len(sel),len(ims)//len(sel)
H,W
# Out:
# (4, 5)

# %%
model_names = {'SAE12': 'SAE-12', 'LVAE12': 'VLAE-12', 'VAE1': 'VAE', 'VAE4': r'$\beta$VAE'}
colnames = ['Input', 'No Update', 'Encoder only', 'Decoder only', 'Both']

side = 1.6

fg, axs = plt.subplots(H, W, figsize=(side*W+0.1,side*H))

imgs = ims.cpu().view(H, W, 3, 64, 64).permute(0,1,3,4,2).cpu().detach().numpy()

for i, (rax, name, row) in enumerate(zip(axs, sel, imgs)):
    
    for ax, col, im in zip(rax, colnames, row):
        plt.sca(ax)
        if i == 0:
            plt.title(col)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(im)
    plt.sca(rax[0])
    plt.ylabel(model_names.get(name,name))
plt.subplots_adjust(hspace=0.0, wspace=0.0, bottom=0.01, top=0.96, left=0.06, right=0.99);

util.save_figure(f'{cut}_extrap_example', root=figure_dir, exts={'png', 'pdf'})
# Out:
# <img src="data:image/png;base64,..." width="810">
# Figure xas_extrap_example saved as {'pdf', 'png'}
